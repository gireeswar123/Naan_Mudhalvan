# %% [markdown]
# ***Load the dataset.***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df = pd.read_csv('/content/drive/MyDrive/HousePriceIndia.csv')
df.head()
# Out:
#            id   Date  number_of_bedrooms  number_of_bathrooms  living_area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot_area  number_of_floors  waterfront_present  number_of_views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition_of_the_house  ...  Built_Year  Renovation_Year  PostalCode  \
# ...

# %% [markdown]
# Perform the Visualizations.***Univariate Analysis***

# %%
sns.distplot(df.Price)
# Out:
# <ipython-input-24-5e080168c38c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.displot(df.Lattitude)

# %%
sns.barplot(x=df.Built_Year.value_counts().index,y=df.Built_Year.value_counts())
# Out:
# <Axes: ylabel='Built_Year'>

# %%
sns.barplot(x=df.Number_of_schools_nearby.value_counts().index,y=df.Number_of_schools_nearby.value_counts())
# Out:
# <Axes: ylabel='Number_of_schools_nearby'>

# %%
plt.pie(df.Number_of_schools_nearby.value_counts(),[0.1, 0, 0],labels=[1,2,3],autopct="%1.1f%%",colors=['red','yellow','blue'],shadow=True)
plt.title('Number_of_schools_nearby')
plt.show()

# %% [markdown]
# ***Bi - Variate Analysis***

# %%
sns.lineplot(x=df.living_area_renov,y=df.lot_area_renov)
# Out:
# <Axes: xlabel='living_area_renov', ylabel='lot_area_renov'>

# %%
sns.scatterplot(x=df.living_area,y=df.lot_area)
# Out:
# <Axes: xlabel='living_area', ylabel='lot_area'>

# %%
sns.lineplot(x=df.living_area,y=df.lot_area)
# Out:
# <Axes: xlabel='living_area', ylabel='lot_area'>

# %% [markdown]
# ***Multi-Variate Analysis***

# %%
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Perform ***descriptive statistics*** on the dataset.

# %%
df.describe()
# Out:
#                  id          Date  number_of_bedrooms  number_of_bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living_area      lot_area  number_of_floors  waterfront_present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# Handle the ***Missing values***.

# %%
df.isnull().any()
# Out:
# id                                        False
# Date                                      False
# number_of_bedrooms                        False
# number_of_bathrooms                       False
# living_area                               False
# lot_area                                  False
# number_of_floors                          False
# waterfront_present                        False
# number_of_views                           False
# condition_of_the_house                    False
# grade_of_the_house                        False
# Area_of_the _house(excluding basement)    False
# Area_of_the_basement                      False
# Built_Year                                False
# Renovation_Year                           False
# PostalCode                                False
# Lattitude                                 False
# Longitude                                 False
# living_area_renov                         False
# lot_area_renov                            False
# ...
